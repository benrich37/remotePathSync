# %% [markdown]
# ### Create your own PathRootPair class with your username(s) and hostname(s) stored in them

# %%
from remotePathSync.pathrootpair import PathRootPair as _PathRootPair
from pathlib import Path


class PathRootPair(_PathRootPair):
    username: str = "username1234"
    hostnames: dict[str, str] = {
        "school": "university.state.edu",
        "personal": "login.something.com"
    }
    remote_roots: dict[str, str] = {
        "school": Path(r"/scratch/u/username1234/"),
        "personal": Path(r"/cloud_storage/u/username1234/"),
    }
    local_roots: dict[str, str] = {
        "school": Path(r"/Users/yourname/school_data/"),
        "personal": Path(r"/Users/yourname/personal_data/"),
    }

# %% [markdown]
# ### Now you can import the new PathRootPair with your usernames/hostnames saved to initialize a PathRootPair with less arguments

# %%
# Not running this as it won't work since all the info is fake.

remote_sync = PathRootPair.from_paths(
    cluster="school",
)
